# %%
using Yao, Yao.AD, YaoExtensions

# %%
n = 4
d = 8
# Out:
# 8

# %%
circuit = dispatch!(variational_circuit(n, d),:random)
# Out:
# nqubits: 4
# chain
# ├─ chain
# │  ├─ chain
# │  │  ├─ put on (1)
# │  │  │  └─ rot(X, 0.5863793060735893)
# │  │  └─ put on (1)
# │  │     └─ rot(Z, 0.39625417084303094)
# │  ├─ chain
# │  │  ├─ put on (2)
# │  │  │  └─ rot(X, 0.764202831265663)
# │  │  └─ put on (2)
# │  │     └─ rot(Z, 0.014014214523067059)
# │  ├─ chain
# │  │  ├─ put on (3)
# │  │  │  └─ rot(X, 0.6778239473977887)
# │  │  └─ put on (3)
# │  │     └─ rot(Z, 0.5717710306447443)
# │  └─ chain
# │     ├─ put on (4)
# │     │  └─ rot(X, 0.027788644876845847)
# │     └─ put on (4)
# │        └─ rot(Z, 0.8945590318615939)
# ├─ chain
# │  ├─ control(1)
# │  │  └─ (2,) X
# │  ├─ control(2)
# │  │  └─ (3,) X
# │  ├─ control(3)
# │  │  └─ (4,) X
# │  └─ control(4)
# │     └─ (1,) X
# ├─ chain
# │  ├─ chain
# │  │  ├─ put on (1)
# │  │  │  └─ rot(Z, 0.6238735799139805)
# │  │  ├─ put on (1)
# │  │  │  └─ rot(X, 0.7044286279333538)
# │  │  └─ put on (1)
# │  │     └─ rot(Z, 0.027835983054811386)
# │  ├─ chain
# │  │  ├─ put on (2)
# │  │  │  └─ rot(Z, 0.4238548202475483)
# │  │  ├─ put on (2)
# │  │  │  └─ rot(X, 0.5156384832865464)
# │  │  └─ put on (2)
# │  │     └─ rot(Z, 0.15503004087572636)
# │  ├─ chain
# │  │  ├─ put on (3)
# │  │  │  └─ rot(Z, 0.7419532232391339)
# │  │  ├─ put on (3)
# │  │  │  └─ rot(X, 0.5775926265686484)
# │  │  └─ put on (3)
# │  │     └─ rot(Z, 0.7567303970770005)
# │  └─ chain
# │     ├─ put on (4)
# │     │  └─ rot(Z, 0.711767166233612)
# │     ├─ put on (4)
# │     │  └─ rot(X, 0.35799493250557846)
# │     └─ put on (4)
# │        └─ rot(Z, 0.5677376838928065)
# ├─ chain
# │  ├─ control(1)
# │  │  └─ (2,) X
# │  ├─ control(2)
# │  │  └─ (3,) X
# │  ├─ control(3)
# │  │  └─ (4,) X
# │  └─ control(4)
# │     └─ (1,) X
# ├─ chain
# │  ├─ chain
# │  │  ├─ put on (1)
# │  │  │  └─ rot(Z, 0.7103252288999089)
# │  │  ├─ put on (1)
# │  │  │  └─ rot(X, 0.16465171208934826)
# │  │  └─ put on (1)
# │  │     └─ rot(Z, 0.600258418799156)
# │  ├─ chain
# │  │  ├─ put on (2)
# │  │  │  └─ rot(Z, 0.0013863191116445517)
# │  │  ├─ put on (2)
# │  │  │  └─ rot(X, 0.1669762455089996)
# │  │  └─ put on (2)
# │  │     └─ rot(Z, 0.5285706209746477)
# │  ├─ chain
# │  │  ├─ put on (3)
# │  │  │  └─ rot(Z, 0.6481407832619903)
# │  │  ├─ put on (3)
# │  │  │  └─ rot(X, 0.11906151963176526)
# │  │  └─ put on (3)
# │  │     └─ rot(Z, 0.2581914756075323)
# │  └─ chain
# │     ├─ put on (4)
# │     │  └─ rot(Z, 0.19753348368250512)
# │     ├─ put on (4)
# │     │  └─ rot(X, 0.4997197094661936)
# │     └─ put on (4)
# │        └─ rot(Z, 0.6149393868315143)
# ├─ chain
# │  ├─ control(1)
# │  │  └─ (2,) X
# │  ├─ control(2)
# │  │  └─ (3,) X
# │  ├─ control(3)
# │  │  └─ (4,) X
# │  └─ control(4)
# │     └─ (1,) X
# ├─ chain
# │  ├─ chain
# │  │  ├─ put on (1)
# │  │  │  └─ rot(Z, 0.13826788562315273)
# │  │  ├─ put on (1)
# │  │  │  └─ rot(X, 0.19457526319533502)
# │  │  └─ put on (1)
# │  │     └─ rot(Z, 0.7048012484205035)
# │  ├─ chain
# │  │  ├─ put on (2)
# │  │  │  └─ rot(Z, 0.8988344869609375)
# │  │  ├─ put on (2)
# │  │  │  └─ rot(X, 0.4581278722428641)
# │  │  └─ put on (2)
# │  │     └─ rot(Z, 0.3425300299741061)
# │  ├─ chain
# │  │  ├─ put on (3)
# │  │  │  └─ rot(Z, 0.11737509301522664)
# │  │  ├─ put on (3)
# │  │  │  └─ rot(X, 0.8371854122232614)
# │  │  └─ put on (3)
# │  │     └─ rot(Z, 0.68017821518636)
# │  └─ chain
# │     ├─ put on (4)
# │     │  └─ rot(Z, 0.19774089439486775)
# │     ├─ put on (4)
# │     │  └─ rot(X, 0.03872503676936012)
# │     └─ put on (4)
# │        └─ rot(Z, 0.2177019076107436)
# ├─ chain
# │  ├─ control(1)
# │  │  └─ (2,) X
# │  ├─ control(2)
# │  │  └─ (3,) X
# │  ├─ control(3)
# │  │  └─ (4,) X
# │  └─ control(4)
# │     └─ (1,) X
# ├─ chain
# │  ├─ chain
# │  │  ├─ put on (1)
# │  │  │  └─ rot(Z, 0.5659846295599764)
# │  │  ├─ put on (1)
# │  │  │  └─ rot(X, 0.6600845383161522)
# │  │  └─ put on (1)
# │  │     └─ rot(Z, 0.3138982207500356)
# │  ├─ chain
# │  │  ├─ put on (2)
# │  │  │  └─ rot(Z, 0.36767760098538593)
# │  │  ├─ put on (2)
# │  │  │  └─ rot(X, 0.9157761467282317)
# │  │  └─ put on (2)
# │  │     └─ rot(Z, 0.6681568981463739)
# │  ├─ chain
# │  │  ├─ put on (3)
# │  │  │  └─ rot(Z, 0.6956060041693837)
# │  │  ├─ put on (3)
# │  │  │  └─ rot(X, 0.11394142591524381)
# │  │  └─ put on (3)
# │  │     └─ rot(Z, 0.6208558850450823)
# │  └─ chain
# │     ├─ put on (4)
# │     │  └─ rot(Z, 0.5086998020318736)
# │     ├─ put on (4)
# │     │  └─ rot(X, 0.920289443251797)
# │     └─ put on (4)
# │        └─ rot(Z, 0.800440813340374)
# ├─ chain
# │  ├─ control(1)
# │  │  └─ (2,) X
# │  ├─ control(2)
# │  │  └─ (3,) X
# │  ├─ control(3)
# │  │  └─ (4,) X
# │  └─ control(4)
# │     └─ (1,) X
# ├─ chain
# │  ├─ chain
# │  │  ├─ put on (1)
# │  │  │  └─ rot(Z, 0.33779224288726817)
# │  │  ├─ put on (1)
# │  │  │  └─ rot(X, 0.9857636127753342)
# │  │  └─ put on (1)
# │  │     └─ rot(Z, 0.436264889050459)
# │  ├─ chain
# │  │  ├─ put on (2)
# │  │  │  └─ rot(Z, 0.208270813590278)
# │  │  ├─ put on (2)
# │  │  │  └─ rot(X, 0.8527788182067901)
# │  │  └─ put on (2)
# │  │     └─ rot(Z, 0.42377775186628797)
# │  ├─ chain
# │  │  ├─ put on (3)
# │  │  │  └─ rot(Z, 0.7251797546817431)
# │  │  ├─ put on (3)
# │  │  │  └─ rot(X, 0.12664376030544577)
# │  │  └─ put on (3)
# │  │     └─ rot(Z, 0.58735412742841)
# │  └─ chain
# │     ├─ put on (4)
# │     │  └─ rot(Z, 0.7614205628844126)
# │     ├─ put on (4)
# │     │  └─ rot(X, 0.08850599621020372)
# │     └─ put on (4)
# │        └─ rot(Z, 0.12287234380824841)
# ├─ chain
# │  ├─ control(1)
# │  │  └─ (2,) X
# │  ├─ control(2)
# │  │  └─ (3,) X
# │  ├─ control(3)
# │  │  └─ (4,) X
# │  └─ control(4)
# │     └─ (1,) X
# ├─ chain
# │  ├─ chain
# │  │  ├─ put on (1)
# │  │  │  └─ rot(Z, 0.8951959948939125)
# │  │  ├─ put on (1)
# │  │  │  └─ rot(X, 0.5428292820489851)
# │  │  └─ put on (1)
# │  │     └─ rot(Z, 0.6926023703062418)
# │  ├─ chain
# │  │  ├─ put on (2)
# │  │  │  └─ rot(Z, 0.8949775120789976)
# │  │  ├─ put on (2)
# │  │  │  └─ rot(X, 0.9831479804909926)
# │  │  └─ put on (2)
# │  │     └─ rot(Z, 0.7480254229744683)
# │  ├─ chain
# │  │  ├─ put on (3)
# │  │  │  └─ rot(Z, 0.3909330524748782)
# │  │  ├─ put on (3)
# │  │  │  └─ rot(X, 0.6635707777030011)
# │  │  └─ put on (3)
# │  │     └─ rot(Z, 0.9859812183933285)
# │  └─ chain
# │     ├─ put on (4)
# │     │  └─ rot(Z, 0.17367624736478304)
# │     ├─ put on (4)
# │     │  └─ rot(X, 0.6815321944169515)
# │     └─ put on (4)
# │        └─ rot(Z, 0.536789148931273)
# ├─ chain
# │  ├─ control(1)
# │  │  └─ (2,) X
# │  ├─ control(2)
# │  │  └─ (3,) X
# │  ├─ control(3)
# │  │  └─ (4,) X
# │  └─ control(4)
# │     └─ (1,) X
# ├─ chain
# │  ├─ chain
# │  │  ├─ put on (1)
# │  │  │  └─ rot(Z, 0.21088289066800736)
# │  │  ├─ put on (1)
# │  │  │  └─ rot(X, 0.44254084267612104)
# │  │  └─ put on (1)
# │  │     └─ rot(Z, 0.39440088091649406)
# │  ├─ chain
# │  │  ├─ put on (2)
# │  │  │  └─ rot(Z, 0.4911287344863735)
# │  │  ├─ put on (2)
# │  │  │  └─ rot(X, 0.09953217105935397)
# │  │  └─ put on (2)
# │  │     └─ rot(Z, 0.37332797699462916)
# │  ├─ chain
# │  │  ├─ put on (3)
# │  │  │  └─ rot(Z, 0.8003059436168207)
# │  │  ├─ put on (3)
# │  │  │  └─ rot(X, 0.9815097190451061)
# │  │  └─ put on (3)
# │  │     └─ rot(Z, 0.5408717360392503)
# │  └─ chain
# │     ├─ put on (4)
# │     │  └─ rot(Z, 0.1475682787411874)
# │     ├─ put on (4)
# │     │  └─ rot(X, 0.9524675343704534)
# │     └─ put on (4)
# │        └─ rot(Z, 0.2123450747547948)
# ├─ chain
# │  ├─ control(1)
# │  │  └─ (2,) X
# │  ├─ control(2)
# │  │  └─ (3,) X
# │  ├─ control(3)
# │  │  └─ (4,) X
# │  └─ control(4)
# │     └─ (1,) X
# └─ chain
#    ├─ chain
#    │  ├─ put on (1)
#    │  │  └─ rot(Z, 0.5425207737553328)
#    │  └─ put on (1)
#    │     └─ rot(X, 0.4044055062469156)
#    ├─ chain
#    │  ├─ put on (2)
#    │  │  └─ rot(Z, 0.24611771843055363)
#    │  └─ put on (2)
#    │     └─ rot(X, 0.7841819194110415)
#    ├─ chain
#    │  ├─ put on (3)
#    │  │  └─ rot(Z, 0.718014385702612)
#    │  └─ put on (3)
#    │     └─ rot(X, 0.8937951873594951)
#    └─ chain
#       ├─ put on (4)
#       │  └─ rot(Z, 0.6898840452038193)
#       └─ put on (4)
#          └─ rot(X, 0.10542408812961312)

# %%
gatecount(circuit)
# Out:
# Dict{Type{#s64} where #s64<:AbstractBlock,Int64} with 3 entries:
#   RotationGate{1,Float64,XGate} => 36
#   RotationGate{1,Float64,ZGate} => 64
#   ControlBlock{4,XGate,1,1}     => 32

# %%
nparameters(circuit)
# Out:
# 100

# %%
h = heisenberg(n)
# Out:
# nqubits: 4
# +
# ├─ +
# │  ├─ repeat on (1, 2)
# │  │  └─ X
# │  ├─ repeat on (1, 2)
# │  │  └─ Y
# │  └─ repeat on (1, 2)
# │     └─ Z
# ├─ +
# │  ├─ repeat on (2, 3)
# │  │  └─ X
# │  ├─ repeat on (2, 3)
# │  │  └─ Y
# │  └─ repeat on (2, 3)
# │     └─ Z
# ├─ +
# │  ├─ repeat on (3, 4)
# │  │  └─ X
# │  ├─ repeat on (3, 4)
# │  │  └─ Y
# │  └─ repeat on (3, 4)
# │     └─ Z
# └─ +
#    ├─ repeat on (4, 1)
#    │  └─ X
#    ├─ repeat on (4, 1)
#    │  └─ Y
#    └─ repeat on (4, 1)
#       └─ Z

# %%
dispatch!(circuit, :random)
for i in 1:100
      _, grad = expect'(h, zero_state(n) => circuit)
      dispatch!(-, circuit, 1e-2 * grad)
      println("Step $i, energy = $(real.(expect(h, zero_state(n)=>circuit)))")
end

using LinearAlgebra
w, _ = eigen(Matrix(mat(h)))
# Out:
# Step 1, energy = -1.7769739728157872
# Step 2, energy = -2.137717615645254
# Step 3, energy = -2.473133445114834
# Step 4, energy = -2.785959943059816
# Step 5, energy = -3.0802229705429625
# Step 6, energy = -3.359841844208262
# Step 7, energy = -3.6279317000210978
# Step 8, energy = -3.8866246330231684
# Step 9, energy = -4.137167821190923
# Step 10, energy = -4.380121212234709
# Step 11, energy = -4.615559753175402
# Step 12, energy = -4.843243277666671
# Step 13, energy = -5.062747785946021
# Step 14, energy = -5.273563811584726
# Step 15, energy = -5.475169778622685
# Step 16, energy = -5.667086619902988
# Step 17, energy = -5.848917591140786
# Step 18, energy = -6.020375476063963
# Step 19, energy = -6.181298516593115
# Step 20, energy = -6.331656236355757
# Step 21, energy = -6.471546539834982
# Step 22, energy = -6.601185779745911
# Step 23, energy = -6.72089370446894
# Step 24, energy = -6.831075239524491
# Step 25, energy = -6.932200915258057
# Step 26, energy = -7.024787468771885
# Step 27, energy = -7.1093797836345365
# Step 28, energy = -7.186534947337378
# Step 29, energy = -7.256808852192494
# Step 30, energy = -7.3207454709726845
# Step 31, energy = -7.378868717529162
# Step 32, energy = -7.431676654848466
# Step 33, energy = -7.47963772967689
# Step 34, energy = -7.523188680697778
# Step 35, energy = -7.562733772010488
# Step 36, energy = -7.598645032241948
# Step 37, energy = -7.63126322126267
# Step 38, energy = -7.660899293117259
# Step 39, energy = -7.687836169896155
# Step 40, energy = -7.712330683489187
# Step 41, energy = -7.734615578728266
# Step 42, energy = -7.754901501757448
# Step 43, energy = -7.773378921719626
# Step 44, energy = -7.790219952610617
# Step 45, energy = -7.805580056209585
# Step 46, energy = -7.81959961719192
# Step 47, energy = -7.832405388662404
# Step 48, energy = -7.844111811120589
# Step 49, energy = -7.854822210881002
# Step 50, energy = -7.864629885700799
# Step 51, energy = -7.873619086195923
# Step 52, energy = -7.8818659018416115
# Step 53, energy = -7.889439060169931
# Step 54, energy = -7.896400647349786
# Step 55, energy = -7.902806757774232
# Step 56, energy = -7.908708079658304
# Step 57, energy = -7.914150423019238
# Step 58, energy = -7.919175195798028
# Step 59, energy = -7.92381983330581
# Step 60, energy = -7.928118185649012
# Step 61, energy = -7.9321008673063735
# Step 62, energy = -7.935795572598855
# Step 63, energy = -7.939227360407219
# Step 64, energy = -7.942418911147688
# Step 65, energy = -7.945390758710278
# Step 66, energy = -7.9481614997925725
# Step 67, energy = -7.950747982818516
# Step 68, energy = -7.953165478417171
# Step 69, energy = -7.955427833242432
# Step 70, energy = -7.957547608742956
# Step 71, energy = -7.9595362063359705
# Step 72, energy = -7.961403980299922
# Step 73, energy = -7.963160339575276
# Step 74, energy = -7.964813839549777
# Step 75, energy = -7.966372264801551
# Step 76, energy = -7.967842703681791
# Step 77, energy = -7.9692316155342535
# Step 78, energy = -7.970544891272673
# Step 79, energy = -7.971787907968867
# Step 80, energy = -7.972965578041142
# Step 81, energy = -7.974082393576113
# Step 82, energy = -7.975142466265828
# Step 83, energy = -7.976149563394836
# Step 84, energy = -7.977107140269963
# Step 85, energy = -7.97801836944733
# Step 86, energy = -7.978886167075684
# Step 87, energy = -7.979713216644569
# Step 88, energy = -7.980501990396761
# Step 89, energy = -7.9812547686388715
# Step 90, energy = -7.9819736571608715
# Step 91, energy = -7.98266060295399
# Step 92, energy = -7.983317408397809
# Step 93, energy = -7.983945744069999
# Step 94, energy = -7.984547160316829
# Step 95, energy = -7.985123097708602
# Step 96, energy = -7.985674896491745
# Step 97, energy = -7.98620380513799
# Step 98, energy = -7.98671098808066
# Step 99, energy = -7.98719753271935
# Step 100, energy = -7.987664455765729
# Eigen{Complex{Float64},Float64,Array{Complex{Float64},2},Array{Float64,1}}
# values:
# 16-element Array{Float64,1}:
#  -7.9999999999999964
#  -4.0
#  -3.9999999999999956
#  -3.999999999999994
#  -7.437659514860159e-32
#  -4.426399962566284e-32
#   0.0
#   2.7369110631344083e-48
#   2.003298162163793e-32
#   3.552713678800501e-15
#   4.440892098500626e-15
#   3.9999999999999987
#   3.9999999999999996
#   4.0
#   4.0
#   4.0
# vectors:
# 16×16 Array{Complex{Float64},2}:
#       0.0+0.0im          0.0+0.0im  …  1.0+0.0im   0.0+0.0im  0.0+0.0im
#       0.0+0.0im          0.0+0.0im     0.0+0.0im   0.0+0.0im  0.0+0.0im
#       0.0+0.0im          0.0+0.0im     0.0+0.0im   0.0+0.0im  0.0+0.0im
#  0.288675+0.0im  9.56933e-17+0.0im     0.0+0.0im   0.0+0.0im  0.0+0.0im
#       0.0+0.0im          0.0+0.0im     0.0+0.0im   0.0+0.0im  0.0+0.0im
#  -0.57735+0.0im     0.707107+0.0im  …  0.0+0.0im   0.0+0.0im  0.0+0.0im
#  0.288675+0.0im  9.56933e-17+0.0im     0.0+0.0im   0.0+0.0im  0.0+0.0im
#       0.0+0.0im          0.0+0.0im     0.0+0.0im  -0.5+0.0im  0.0+0.0im
#       0.0+0.0im          0.0+0.0im     0.0+0.0im   0.0+0.0im  0.0+0.0im
#  0.288675+0.0im  9.56933e-17+0.0im     0.0+0.0im   0.0+0.0im  0.0+0.0im
#  -0.57735+0.0im    -0.707107+0.0im  …  0.0+0.0im   0.0+0.0im  0.0+0.0im
#       0.0+0.0im          0.0+0.0im     0.0+0.0im  -0.5+0.0im  0.0+0.0im
#  0.288675+0.0im          0.0+0.0im     0.0+0.0im   0.0+0.0im  0.0+0.0im
#       0.0+0.0im          0.0+0.0im     0.0+0.0im  -0.5+0.0im  0.0+0.0im
#       0.0+0.0im          0.0+0.0im     0.0+0.0im  -0.5-0.0im  0.0+0.0im
#       0.0+0.0im          0.0+0.0im  …  0.0+0.0im   0.0+0.0im  1.0+0.0im

# %%
dispatch!(circuit, :random)
expect(h, zero_state(n) => circuit)
# Out:
# 0.5491420403695688 - 1.3877787807814457e-17im
